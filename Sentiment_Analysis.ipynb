# %% [markdown]
# # Twitter Sentiment Analysis

# %%
#data link: https://raw.githubusercontent.com/laxmimerit/twitter-data/5d206f3032facf614c62f403cb823f4a84c39677/twitt30k.csv

# %%
import numpy as np
import pandas as pd

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
df=pd.read_csv('https://raw.githubusercontent.com/laxmimerit/twitter-data/5d206f3032facf614c62f403cb823f4a84c39677/twitt30k.csv')

# %%
df
# Out:
#                                                   twitts  sentiment
# 0           @robbiebronniman Sounds like a great night.           1
# 1      Damn the person who stolde my wallet !!!!!  Ma...          1
# 2      Greetings from the piano bench  (photo) http:/...          1
# 3      @drewryanscott i love it!! i love you!! haha f...          1
# 4      @kissthestars Pretty pretty pretty please, pak...          0
# ...                                                  ...        ...
# 29995  @Calumfan1 is it in any way related to photosh...          0
# 29996                   @Swiz_NZ really? wow thats crap           0
# 29997  At the 2010 lexus HS250h press event.  Again, ...          0
# 29998  @karmicunderpath ooooh now there's a nice thou...          1
# 29999  @mariap91 i'd usually ask you about the sun an...          1
#
# [30000 rows x 2 columns]

# %%
df['sentiment'].value_counts()
# Out:
# 1    15000
# 0    15000
# Name: sentiment, dtype: int64

# %% [markdown]
# #SVM Model and Data Preparation

# %% [markdown]
# # SVM Model and Data Preparation

# %%
def run_svm(df):
    X=df['twitts']
    y=df['sentiment']
    tfidf=TfidfVectorizer(norm='l1',ngram_range=(1,2), analyzer='word',max_features=5000)
    X=tfidf.fit_transform(X)
    X
    X_train, X_test,y_train, y_test=train_test_split(X,y,test_size=0.2,random_state=0,stratify=y)
    print('shape of X:', X.shape)
    clf=LinearSVC()
    clf.fit(X_train, y_train)
    y_pred=clf.predict(X_test)
    print()
    print('Printing Report')
    print(classification_report(y_test,y_pred))
    return tfidf, clf
run_svm(df)
# Out:
# shape of X: (30000, 5000)
#
# Printing Report
#               precision    recall  f1-score   support
#
#            0       0.75      0.77      0.76      3000
#            1       0.77      0.75      0.76      3000
#
#     accuracy                           0.76      6000
#    macro avg       0.76      0.76      0.76      6000
# weighted avg       0.76      0.76      0.76      6000
# (TfidfVectorizer(max_features=5000, ngram_range=(1, 2), norm='l1'),
#  LinearSVC())

# %%
# %%time
tfidf, clf=run_svm(df)
# Out:
# shape of X: (30000, 40854)
#
# Printing Report
#               precision    recall  f1-score   support
#
#            0       0.75      0.74      0.75      3000
#            1       0.74      0.75      0.75      3000
#
#     accuracy                           0.75      6000
#    macro avg       0.75      0.75      0.75      6000
# weighted avg       0.75      0.75      0.75      6000
#
# CPU times: total: 984 ms
# Wall time: 992 ms

# %%
x=['i am really happy. thanks a lot for coming with me']

# %%
clf.predict(tfidf.transform(x))
# Out:
# array([1], dtype=int64)

# %% [markdown]
# # Saving and Loading ML Model

# %%
import pickle

# %%
tfidf
# Out:
# TfidfVectorizer()

# %%
pickle.dump(clf, open('clf.pkl','wb'))
pickle.dump(tfidf, open('tfidf.pkl','wb'))

# %%
del clf
del tfidf

# %%
clf=pickle.load(open('clf.pkl','rb'))
tfidf=pickle.load(open('tfidf.pkl','rb'))

# %%
clf
# Out:
# LinearSVC()

# %%
tfidf.vocabulary_
# Out:
# {'robbiebronniman': 30399,
#  'sounds': 33426,
#  'like': 21191,
#  'great': 15125,
#  'night': 25532,
#  'damn': 9461,
#  'the': 35695,
#  'person': 27468,
#  'who': 39246,
#  'stolde': 34156,
#  'my': 24822,
#  'wallet': 38688,
#  'may': 22979,
#  'karma': 19511,
#  'come': 8240,
#  'back': 4046,
#  'and': 2865,
#  'bite': 5087,
#  'you': 40422,
#  'in': 17367,
#  'ass': 3597,
#  'greetings': 15172,
#  'from': 13944,
#  'piano': 27678,
#  'bench': 4748,
#  'photo': 27635,
#  'http': 16751,
#  'twitpic': 37407,
#  'com': 8229,
#  '6oe8i': 1133,
#  'drewryanscott': 11172,
#  'love': 21828,
#  'it': 17901,
#  'haha': 15500,
#  'forget': 13641,
#  'hug': 16768,
#  'should': 32346,
#  'give': 14670,
#  'me': 23095,
#  'kiss': 20071,
#  'no': 25676,
#  'lie': 21133,
#  'please': 27958,
#  'would': 39744,
#  'be': 4465,
#  'awesome': 3878,
#  'if': 17125,
#  'did': 10384,
#  'kissthestars': 20081,
#  'pretty': 28470,
#  'pakidownload': 26892,
#  'ito': 17929,
#  'then': 35865,
# ...

# %%
clf.predict(tfidf.transform(x))
# Out:
# array([1], dtype=int64)

# %% [markdown]
# # Real Time Twitter Sentiment Analysis

# %%
consumer_key='yGqw96GBMwmrC75FzI2JCJ9Ej'
consumer_secret='liWhRBk5XBo9brBS3tCYWLPY5t3NYYDNN0kWKoeCxuuffAamTZ'
access_token='1699055913422970880-jML1UGkNLylDjQSIXiQ3JKMFAd1cT4'
access_token_secret='JiAiLmmLiLFZUEJMdItpbYsdkehC1Mh4e9upRaI26hfo9'

# %%
# !pip install tweepy

# %%
# !pip install requests
# !pip install requests-oauthlib

# %%
#import tweepy
#auth=tweepy.OAuthHandler(consumer_key, consumer_secret)
#auth.set_access_token(access_token, access_token_secret)
#api=tweepy.API(auth)
#public_tweets=api.home_timeline()
#for tweet in public_tweets:
 #   print(tweet.text)
